# %% [markdown]
# # Principal Component Analysis (PCA) Hello World
#
# Principal Component Analysis (PCA) is a dimensionality reduction method for illustrating the feasiblilty of data-related projects. By reducing many features into 1-2 dimension, it can visualize some hidden relationship of the data and the label. Also, it could be used to reduce noises in the data by finding the most representative data points.
#
# **Reference:**
# - https://jakevdp.github.io/PythonDataScienceHandbook/05.09-principal-component-analysis.html
# - https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html

# %%
# Load example dataset from scikit-learn dataset library
from sklearn import datasets
(wine_data, wine_target) = datasets.load_wine(return_X_y=True)

# %%
import numpy as np
from sklearn.decomposition import PCA

# Fit the data to PCA model 
pca = PCA(n_components=2)  # Dimensionality = 2
pca.fit(wine_data)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
# print useful statistics
print(pca.components_)
print(pca.explained_variance_)
print(pca.explained_variance_ratio_)
# Out:
# [[ 1.65926472e-03 -6.81015556e-04  1.94905742e-04 -4.67130058e-03
#    1.78680075e-02  9.89829680e-04  1.56728830e-03 -1.23086662e-04
#    6.00607792e-04  2.32714319e-03  1.71380037e-04  7.04931645e-04
#    9.99822937e-01]
#  [ 1.20340617e-03  2.15498184e-03  4.59369254e-03  2.64503930e-02
#    9.99344186e-01  8.77962152e-04 -5.18507284e-05 -1.35447892e-03
#    5.00440040e-03  1.51003530e-02 -7.62673115e-04 -3.49536431e-03
#   -1.77738095e-02]]
# [99201.78951748   172.53526648]
# [0.99809123 0.00173592]

# %%
# Apply dimensionality reduction
wine_pca = pca.transform(wine_data)
print("original shape:   ", wine_data.shape)
print("transformed shape:", wine_pca.shape)
# Out:
# original shape:    (178, 13)
# transformed shape: (178, 2)

# %%
import matplotlib.pyplot as plt

# Draw Output
plt.scatter(wine_pca[:, 0], wine_pca[:, 1], c=wine_target, cmap=plt.cm.get_cmap('Spectral', 3), alpha=0.8)
plt.colorbar();
